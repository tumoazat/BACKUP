# %% [markdown]
# <a href="https://colab.research.google.com/github/tumoazat/BACKUP/blob/main/Assignment_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment: Housing Price Prediction with Linear Regression**

# %% [markdown]
# You are given a dataset containing **California housing data**, which includes various features describing homes (such as average income, average house age, number of rooms, etc.) and their corresponding median house prices.
#
#
# Your task is to build and evaluate a regression model capable of accurately predicting the median price of houses. Specifically, you will implement and explore linear regression with polynomial feature transformations and apply L2-regularization to control the model's complexity. The goal is to investigate how different choices of model parameters influence the trade-off between bias and variance.
#
#
# **Dataset**
# Use the built-in **California Housing dataset** provided by **scikit-learn**:
# *   Number of samples: ~20,000
# *   Number of features: 8 real-valued attributes
# *   Target variable: Median house value

# %% [markdown]
# **1. (Baseline Model)**
#
# Fit a standard Linear Regression model using the provided training data.
#
# Evaluate its performance by computing the Mean Squared Error (MSE) for both the training and test sets.
#
# Discuss whether the model shows signs of under-fitting, over-fitting, or good generalization performance based on these metrics.

# %%
#Code here

# %% [markdown]
# **2. (Effect of Polynomial Degree d)**
#
# Perform polynomial feature expansion with degrees **d=1,2,3,4,5**.
#
# Train a linear regression model for each degree and calculate the RMSE on both training and test sets.
#
# Discuss how varying the polynomial degree affects model complexity, and how this relates to the bias–variance trade-off. Clearly identify which polynomial degree results in the optimal balance between training and test performance.

# %%
#Code here

# %% [markdown]
# **3. (Effect of Regularization Strength λ)**
# Implement Ridge regression (linear regression with L2-regularization).
#
# Use 5-fold cross-validation to systematically choose the best regularization parameter **λ** from the set **λ** ∈ {10^-4, 10^-3, 10^-1,10,100,1000}. After selecting the optimal **λ**, evaluate the resulting model on the test set.
#
# Explain clearly how increasing the regularization strength affects the bias and variance of the model.

# %%
#Code here

# %% [markdown]
# **4. (Effect of Training Set Size n)**
#
# Use the optimal **λ found previously**, and train separate models using training subsets of sizes **n=500,1000, 5000**, and the full training set.
#
# Plot the training and test MSE against the number of training samples.
#
# Discuss how increasing the size of the training set influences variance and the model’s generalization performance.

# %%
#Code here
